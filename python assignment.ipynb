# %%
 Ans 1 =
Use a for loop to iterate over an array. Use a for loop when you know the loop should execute n times.
Use a while loop for reading a file into a variable. Use a while loop when asking for user input

"for loop example"
l= [ 1,2,3,4,5 ]
for i in l :
    print (i, type(i)) 
1 <class 'int'>
2 <class 'int'>
3 <class 'int'>
4 <class 'int'>
5 <class 'int'>
"while loop example"
number = int(input("enter your number"))
factorial = 1
while number > 0 :
    factorial = factorial * number
    number = number - 1
factorial
enter your number 5
16

Ans 2=
"program using while loop"
n = int(input("enter a number: "))
i = 1
sum = 0
while (i <= n):
    sum = sum + i
    i = i + 1
print("The sum is: ", sum)
"program using for loop"
sum = 0 
for i in range(1, 11): 
  sum += i 
print(sum) 


Ans 3 =
"program to calculate electricity bill"
def calculateBill(units):
 
    # Condition to find the charges
    # bar in which the units consumed
    # is fall
    if (units <= 100):
      
        return units * 4.5;
     
    elif (units <= 200):
     
        return ((100 * 4.5) +
                (units - 100) * 6);
     
    elif (units <= 300):
      
        return ((100 * 4.5) +
                (100 * 6) +
                (units - 200) * 10);
     
    elif (units > 300):
     
        return ((100 * 4.5) +
                (100 * 6) +
                (100 * 10) +
                (units - 300) * 20);
     
    return 0;
output:
input= 250
print (calculateBill(units))
1550.0


Ans 4 =
x=[] 
for i in range(1,51): 
	x.append(i**3) 
print(x)
 output :
     [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000, 1331, 1728, 2197, 2744, 3375, 4096, 4913, 5832, 6859, 8000, 9261, 10648,
      12167, 13824, 15625, 17576, 19683, 21952, 24389, 27000, 29791, 32768, 35937, 39304, 42875, 46656, 50653, 54872, 59319,
      64000, 68921, 74088, 79507, 85184, 91125, 97336, 103823, 110592, 117649, 125000] 
    
    
Ans 5 = 
    Program 
ip_str = input("Enter a string: ")

ip_str = ip_str.casefold()
count = {x:sum([1 for char in ip_str if char == x]) for x in 'aeiou'}

print(count)
Output:
    Enter a string:  "I want to become a data scientist"
{'a': 4, 'e': 3, 'i': 3, 'o': 2, 'u': 0}
